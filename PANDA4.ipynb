# %%
import pandas as pd
import matplotlib.pyplot as plt
#read the CSV file with specified columns
#usecols parameter to extract only two required columns
data=pd.read_csv("F:\\APS\\class_12\\Min_Max_Seasonal_IMD_2017.csv",usecols=['ANNUAL - MIN','ANNUAL - MAX'])
df=pd.DataFrame(data)
#plot histogram for 'ANNUAL - MIN'
df.plot(kind='hist',y='ANNUAL - MIN',title='Annual Minimum Temperature (1901-2017)')
plt.xlabel('Temperature')
plt.ylabel('Number of times')
#plot histogram for both 'ANNUAL - MIN' and 'ANNUAL - MAX'
df.plot(kind='hist',title='Annual Min and Max Temperature (1901-2017)',color=['blue','red'])
plt.xlabel('Temperature')
plt.ylabel('Number of times')
# Out:
# Text(0, 0.5, 'Number of times')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("F:\\APS\\class_12\\Min_Max_Seasonal_IMD_2017.csv",usecols=['ANNUAL - MIN'])
df=pd.DataFrame(data)
#convert the 'ANNUAL - MIN' column into a numpy 1D array
minarray=np.array([df['ANNUAL - MIN']])
# Extract y (frequency) and edges (bins)
y,edges = np.histogram(minarray)
#calculate the midpoint for each bar on the histogram
mid = 0.5*(edges[1:]+ edges[:-1])
df.plot(kind='hist',y='ANNUAL - MIN')
plt.plot(mid,y,'-^')
plt.title('Annual Min Temperature plot(1901 - 2017)')
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')

# %%
minarray
# Out:
# array([[19.51, 19.44, 19.25, 19.22, 19.03, 19.51, 19.08, 19.09, 19.13,
#         19.01, 19.31, 19.27, 19.09, 19.41, 19.64, 19.34, 19.02, 19.02,
#         19.37, 19.07, 19.54, 19.32, 19.36, 19.52, 19.24, 19.37, 19.3 ,
#         19.61, 19.4 , 19.21, 19.73, 19.32, 19.35, 19.22, 19.21, 19.53,
#         19.25, 19.28, 19.16, 19.24, 19.85, 19.45, 19.06, 19.18, 18.89,
#         19.38, 19.23, 19.49, 19.28, 18.95, 19.36, 19.51, 19.71, 19.33,
#         19.19, 19.29, 19.3 , 19.92, 19.6 , 19.27, 19.27, 19.2 , 19.28,
#         19.11, 18.98, 19.31, 19.08, 18.83, 19.32, 19.16, 18.77, 18.91,
#         19.38, 18.76, 18.62, 18.9 , 19.31, 19.25, 19.55, 19.53, 19.25,
#         19.21, 19.14, 19.25, 19.3 , 19.09, 19.42, 19.33, 18.96, 19.29,
#         19.29, 19.15, 19.34, 19.48, 20.39, 19.55, 19.21, 19.84, 19.53,
#         19.48, 19.49, 19.78, 19.7 , 19.69, 19.58, 20.07, 19.69, 19.6 ,
#         19.94, 20.15, 19.58, 19.54, 19.83, 19.77, 19.96, 21.28, 21.17]])

# %%
y
# Out:
# array([ 4, 21, 50, 24, 12,  3,  1,  0,  0,  2], dtype=int64)

# %%
edges
# Out:
# array([18.62 , 18.886, 19.152, 19.418, 19.684, 19.95 , 20.216, 20.482,
#        20.748, 21.014, 21.28 ])
